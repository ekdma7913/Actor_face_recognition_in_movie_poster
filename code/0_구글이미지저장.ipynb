# %%
'''from selenium import webdriver

from selenium.webdriver.common.keys import Keys

import urllib.request'''

# %%
'''driver = webdriver.Chrome() # 크롬드라이버 설치한 경로 작성 필요 

driver.get("https://www.google.co.kr/imghp?hl=ko&tab=wi&authuser=0&ogbl") # 구글 이미지 검색 url

elem = driver.find_element_by_name("q") #구글 검색창 선택
elem.send_keys("오달수") # 검색창에 검색할 내용(name)넣기

elem.send_keys(Keys.RETURN) # 검색할 내용을 넣고 enter를 치는것!'''
# Out:
# /var/folders/l9/xyk822g16sl49q_kknpsjxtm0000gn/T/ipykernel_22887/4278290565.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_name("q") #구글 검색창 선택

# %%
'''imgs = driver.find_elements_by_css_selector(".rg_i.Q4LuWd") #작게 뜬 이미지들 모두 선택(elements)

count = 1
    #저장할 경로/Users/yu/tf39_test/실습/영화포스터 배우얼굴인식/actor
for img in imgs:
    try:
        img.click()
        time.sleep(2)
        imgUrl = driver.find_element_by_xpath(
                '//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div[1]/a/img').get_attribute(
                "src") # 크게 뜬 이미지 선택하여 "src" 속성을 받아옴
        path = "/Users/yu/tf39_test/실습/영화포스터 배우얼굴인식/actor/"
        urllib.request.urlretrieve(imgUrl, path + "오달수" + str(count) + ".jpg")
        count = count + 1
        if count > 10: #다운 받을 이미지 갯수 조정
            break
    except:
        pass
driver.close()'''
# Out:
# /var/folders/l9/xyk822g16sl49q_kknpsjxtm0000gn/T/ipykernel_22887/1876883057.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   imgs = driver.find_elements_by_css_selector(".rg_i.Q4LuWd") #작게 뜬 이미지들 모두 선택(elements)

# %%
from selenium import webdriver
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
import os

# %%
if not os.path.isdir("actor/"):
    os.makedirs("actor/")

driver = webdriver.Chrome()
driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")

search = "류승룡"
elem = driver.find_element_by_name("q")
elem.send_keys(search)
elem.send_keys(Keys.RETURN)

SCROLL_PAUSE_TIME = 1

last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        try:
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_height = new_height

images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
count = 1

for image in images:
    try:
        image.click()
        time.sleep(2)
        imgUrl = driver.find_element_by_xpath("//*[@id='Sva75c']/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div/a/img").get_attribute('src')
        urllib.request.urlretrieve(imgUrl, "actor/" + search + "_" + str(count) + ".jpg")
        print("Image saved: 류승룡_{}.jpg".format(count))
        count += 1
    except:
        pass

driver.close()
# Out:
# /var/folders/l9/xyk822g16sl49q_kknpsjxtm0000gn/T/ipykernel_11493/3950892024.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_name("q")
# /var/folders/l9/xyk822g16sl49q_kknpsjxtm0000gn/T/ipykernel_11493/3950892024.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(".mye4qd").click()
# /var/folders/l9/xyk822g16sl49q_kknpsjxtm0000gn/T/ipykernel_11493/3950892024.py:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
# /var/folders/l9/xyk822g16sl49q_kknpsjxtm0000gn/T/ipykernel_11493/3950892024.py:35: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   imgUrl = driver.find_element_by_xpath("//*[@id='Sva75c']/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/